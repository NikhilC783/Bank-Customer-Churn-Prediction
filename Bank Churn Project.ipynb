# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"C:\Users\chand\Downloads\archive\Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age']
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
df.drop(['RowNumber','CustomerId', 'Surname' ], axis=1, inplace= True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %% [markdown]
# ### this is imbalance dataset

# %%
sns.countplot(data = df, x = 'Exited', color='#FE4854')
plt.show()

# %%
sns.countplot(data = df, x = 'Geography', hue='Exited', color= '#F825C6')
plt.show()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_39892\1275108322.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#F825C6'` for the same effect.
#
#   sns.countplot(data = df, x = 'Geography', hue='Exited', color= '#F825C6')

# %%
sns.histplot(data=df, x = 'Age', color='#00DCD6')
plt.show()

# %%
sns.boxplot(data=df, x = 'Age', color='#3D1054')
plt.show()

# %%
sns.boxplot(data=df, x = 'Tenure', color='#FD6536')
plt.show()

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
sns.histplot(data=df, x = 'Tenure', color='#0A5E2B')
plt.show()

# %%
sns.boxplot(data=df, x = 'Balance', color='#FE0000')
plt.show()

# %%
sns.histplot(data=df, x = 'Balance', color='#C905E2')
plt.show()

# %%
sns.boxplot(data=df,x = 'Exited', y = 'Balance', color='#EFFE07')
plt.show()

# %%
co = df.select_dtypes(['int', 'float']).corr()
sns.heatmap(co)
plt.show()

# %%
co = df.select_dtypes(include=['int', 'float']).corr()

sns.heatmap(co, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Outlier

q1 = df['Age'].quantile(.25)
q3 = df['Age'].quantile(.75)

iqr = q3 - q1
lbv = q1 - (1.5 * iqr)
hbv = q3 + (1.5 * iqr)

df.loc[(df['Age'] >= lbv) & (df['Age'] <= hbv)]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df['Age'].describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
# Feature Engineering

# %%
num_cols = df.select_dtypes(['int', 'float']).columns
cat_cols = df.select_dtypes(['object']).columns

# %%
df[cat_cols]
# Out:
#      Geography  Gender
# 0       France  Female
# 1        Spain  Female
# 2       France  Female
# 3       France  Female
# 4        Spain  Female
# ...        ...     ...
# 9995    France    Male
# 9996    France    Male
# 9997    France  Female
# 9998   Germany    Male
# 9999    France  Female
#
# [10000 rows x 2 columns]

# %%
df[cat_cols]['Geography']
# Out:
# 0        France
# 1         Spain
# 2        France
# 3        France
# 4         Spain
#          ...
# 9995     France
# 9996     France
# 9997     France
# 9998    Germany
# 9999     France
# Name: Geography, Length: 10000, dtype: object

# %%
df[cat_cols]['Gender']
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4       Female
#          ...
# 9995      Male
# 9996      Male
# 9997    Female
# 9998      Male
# 9999    Female
# Name: Gender, Length: 10000, dtype: object

# %%
df_cat = pd.get_dummies(df[cat_cols])
df_cat
# Out:
#       Geography_France  Geography_Germany  Geography_Spain  Gender_Female  \
# 0                 True              False            False           True
# 1                False              False             True           True
# 2                 True              False            False           True
# 3                 True              False            False           True
# 4                False              False             True           True
# ...                ...                ...              ...            ...
# 9995              True              False            False          False
# 9996              True              False            False          False
# 9997              True              False            False           True
# 9998             False               True            False          False
# 9999              True              False            False           True
#
#       Gender_Male
# 0           False
# 1           False
# 2           False
# ...

# %%
df[num_cols]
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  1        112542.58       0
# ...

# %%
df[num_cols]['Age']
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
df[num_cols]
[['CreditScore','Age','Balance', 'EstimatedSalary']]
# Out:
# [['CreditScore', 'Age', 'Balance', 'EstimatedSalary']]

# %%
from sklearn.preprocessing import StandardScaler

sts = StandardScaler()
df_num = df[num_cols]
df_num['CreditScore'] = sts.fit_transform(df_num[['CreditScore']])
df_num['Age'] = sts.fit_transform(df_num[['Age']])
df_num['Balance'] = sts.fit_transform(df_num[['Balance']])
df_num['EstimatedSalary'] = sts.fit_transform(df_num[['EstimatedSalary']])
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_39892\2128750964.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num['CreditScore'] = sts.fit_transform(df_num[['CreditScore']])
# C:\Users\chand\AppData\Local\Temp\ipykernel_39892\2128750964.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num['Age'] = sts.fit_transform(df_num[['Age']])
# C:\Users\chand\AppData\Local\Temp\ipykernel_39892\2128750964.py:7: SettingWithCopyWarning:
# ...

# %%
df_clean  = pd.concat([df_num, df_cat], axis =1 )

# %%
X = df_clean.drop('Exited', axis = 1)
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_base = KNeighborsClassifier()
knn_base.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_base.predict(X_test)
y_pred_prob = knn_base.predict_proba(X_test)[:, 1]

y_pred_prob
# Out:
# array([0. , 0. , 0.2, ..., 0.4, 0.2, 0.2], shape=(3000,))

# %%
# Classification

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,\
precision_score, recall_score, roc_auc_score, log_loss, matthews_corrcoef, roc_curve, auc

accuracy_score(y_pred=y_pred, y_true=y_test)
# Out:
# 0.8226666666666667

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2273  134]
#  [ 398  195]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90      2407
#            1       0.59      0.33      0.42       593
#
#     accuracy                           0.82      3000
#    macro avg       0.72      0.64      0.66      3000
# weighted avg       0.80      0.82      0.80      3000

# %%
# AUC area under curve and ROC reciver

# %%
fpr, tpr, thersholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_auc
# Out:
# 0.7514994559852481

# %%
plt.plot(fpr, tpr, label = f"KNN(AUC = {roc_auc :.3f})", color = "Red")
plt.plot([0,1], [0,1], linestyle = "--", color = "Green")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.show()
